# %%
from tokenizers import (
    models,
    normalizers,
    pre_tokenizers,
    trainers,
    Tokenizer,
)
import math

# %%
#训练分词器
tokenizer = Tokenizer(models.WordPiece(unk_token="[UNK]"))
tokenizer.normalizer = normalizers.Sequence(
    [normalizers.NFD(),normalizers.Lowercase()]
)
tokenizer.pre_tokenizer = pre_tokenizers.WhitespaceSplit()
special_tokens = ["[UNK]","[PAD]","[CLS]","[SEP]","[MASK]"]
trainer = trainers.WordPieceTrainer(vocab_size =1000,special_tokens=special_tokens)

tokenizer.train(["corp.txt"],trainer=trainer)
tokenizer.save("./model_save/my_tokenizer.json")

#使用训练好的分词器
tokenizer = Tokenizer.from_file("./model_save/my_tokenizer.json")
tokens = tokenizer.encode("尽其在我，听其在天")
print(tokens.ids,tokens.tokens)

# %%
# ?tokenizer
# Out:
# Type:        Tokenizer
# String form: <tokenizers.Tokenizer object at 0x7fe2c7a56430>
# File:        /data/yetianxiang/anaconda3/envs/finetune/lib/python3.10/site-packages/tokenizers/__init__.py
# Docstring:
# A :obj:`Tokenizer` works as a pipeline. It processes some raw text as input
# and outputs an :class:`~tokenizers.Encoding`.
#
# Args:
#     model (:class:`~tokenizers.models.Model`):
#         The core algorithm that this :obj:`Tokenizer` should be using.

# %%
torch.cuda.is_available()
# Out:
# True

# %%
#model_config
import torch
import json
class ModelConfig:
    def __init__(self,
                device = torch.device("cuda"),
                vocab_size = None,
                max_len = None,
                hidden_dim = None,
                n_head = None,
                drop_out = None,
                layer_count = None
                ):
                
        self.device = device
        self.vocab_size = vocab_size
        self.max_len = max_len
        self.hidden_dim = hidden_dim
        self.n_head = n_head
        self.drop_out = drop_out
        self.layer_count = layer_count

    
    def save(self,path):
        f = open(path,'w')
        d = {
            "vocab_size":self.vocab_size,
            "max_len":self.max_len,
            "hidden_dim":self.hidden_dim,
            "n_head":self.n_head,
            "drop_out":self.drop_out,
            "layer_count":self.layer_count,
        }
        d = json.dumps(d)
        f.write(d)
        f.close()

    def load(self,path):
        d = open(path).read()
        d = json.loads(d)
        self.vocab_size = d["vocab_size"]
        self.max_len = d["max_len"]
        self.hidden_dim = d["hidden_dim"]
        self.n_head = d["n_head"]
        self.drop_out = d["drop_out"]
        self.layer_count = d["layer_count"]

# %%
import torch.nn as nn
class Embedding(nn.Module):
    def __init__(self,config):
        super(Embedding,self).__init__()
        #id编码
        self.word_embeddings = nn.Embedding(num_embeddings = config.vocab_size,embedding_dim = config.hidden_dim).to(config.device)
        self.position_embeddings = nn.Embedding(num_embeddings = config.max_len,embedding_dim = config.hidden_dim).to(config.device)
        self.token_type_embeddings = nn.Embedding(num_embeddings = 2,embedding_dim = config.hidden_dim).to(config.device)
        self.device = config.device

    def forward(self,input_ids,token_type_ids=None):
        seq_length = input_ids.size(1)
        position_ids = torch.arange(seq_length,dtype = torch.long,device = self.device)
        if token_type_ids is None:
            token_type_ids = torch.zeros_like(input_ids,device = self.device)

        we = self.word_embeddings(input_ids)
        pe = self.position_embeddings(position_ids)
        te = self.token_type_embeddings(token_type_ids)
        return we + pe + te

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,config):
        super(MultiHeadAttention,self).__init__()
        self.n_head = config.n_head
        self.dim = config.hidden_dim
        self.device = config.device

        self.wq = nn.Linear(self.dim,self.dim).to(self.device)
        self.wk = nn.Linear(self.dim,self.dim).to(self.device)
        self.wv = nn.Linear(self.dim,self.dim).to(self.device)

        self.softmax = nn.Softmax(dim=3)
        self.f = nn.Linear(self.dim,self.dim).to(self.device)
        self.norm = nn.LayerNorm(self.dim).to(self.device)
        self.dropout = nn.Dropout(config.drop_out)

    def concat(self,tensor):
        a, b, c, d = tensor.size()
        return tensor.view(a,c,b*d)
    
    def attention(self,q,k,v):
        _, _, _, d = q.size()
        kt = k.transpose(2,3)
        s = (q @ kt)/math.sqrt(d)
        s = self.softmax(s)
        v = s @ v
        return v
    
    def split(self,tensor):
        a,b,c = tensor.size()
        d = c // self.n_head
        return tensor.view(a,self.n_head,b,d)
    
    def forward(self,x):
        q,k,v = self.wq(x),self.wk(x),self.wv(x)
        q,k,v = self.split(q),self.split(k),self.split(v)
        v = self.attention(q,k,v)
        v = self.concat(v)
        vb = v
        v = self.norm(x+v)
        v = self.f(v)
        v = self.norm(vb+v)
        return self.dropout(v)

# %%
class Pooler(nn.Module):
    def __init__(self,config):
        super(Pooler,self).__init__()
        self.dense = nn.Linear(config.hidden_dim,config.hidden_dim).to(config.device)
        self.ac = nn.Tanh()

    def forward(self,x):
        f = x[:,0]
        return self.ac(self.dense(f))

# %%
class Transformer(nn.Module):
    def __init__(self,config):
        super(Transformer,self).__init__()
        self.embedding = Embedding(config)
        self.layers = nn.ModuleList([
            MultiHeadAttention(config) for _ in range(config.layer_count)
        ])
        self.pooler = Pooler(config)
        self.device = config.device

    def forward(self,input_ids,token_type_ids=None):
        em = self.embedding(input_ids,token_type_ids)
        for layer in self.layers:
            em = layer(em)
        p = self.pooler(em)
        return p,em

# %%
import torch.nn.functional as F
class LMPredictHead(nn.Module):
    def __init__(self,config):
        super(LMPredictHead,self).__init__()
        self.f1 = nn.Linear(config.hidden_dim,config.hidden_dim).to(config.device)
        self.f2 = nn.Linear(config.hidden_dim,config.vocab_size).to(config.device)

    def forward(self,x):
        x = F.relu(self.f1(x))
        return self.f2(x)

class SClsHead(nn.Module):
    def __init__(self,config):
        super(SClsHead,self).__init__()
        self.f1 = nn.Linear(config.hidden_dim,config.hidden_dim).to(config.device)
        self.f2 = nn.Linear(config.hidden_dim,2).to(config.device)

    def forward(self,x):
        x = F.relu(self.f1(x))
        return self.f2(x)

# %%
from torch.nn import CrossEntropyLoss
class PretrainModel(nn.Module):
    def __init__(self,config):
        super(PretrainModel,self).__init__()
        self.transformer = Transformer(config)
        self.wm = LMPredictHead(config)
        self.scls = SClsHead(config)
        self.loss_function = CrossEntropyLoss(ignore_index=-1)
        self.config = config

    def forward(self,input_ids,token_type_ids=None,masked_lm_labels=None,next_sentence_labels=None):
        p,e = self.transformer(input_ids,token_type_ids)
        wmp = self.wm(e)
        sclsp = self.scls(p)

        if masked_lm_labels is not None and next_sentence_labels is not None:
            loss1 = self.loss_function(wmp.view(-1,self.config.vocab_size),masked_lm_labels.reshape(-1))
            loss2 = self.loss_function(sclsp.view(-1,2),next_sentence_labels.view(-1))
            return loss1 + loss2
        return wmp,sclsp

# %%
t = torch.rand(20,103,128)
t.view(-1,103).size()
# Out:
# torch.Size([2560, 103])

# %%
from tqdm import tqdm
import torch.optim as optim
import numpy as np
import random
from torch.utils.data import Dataset,DataLoader

class PretrainDataset(Dataset):
    def __init__(self):
        self.tokenizer = Tokenizer.from_file("./model_save/my_tokenizer.json")
        lines = open("corp.txt",encoding="utf8").readlines()
        ds  = []
        for line in tqdm(lines):
            line = line.strip()
            if line == '':
                continue
            ts = line.split("。")
            if len(ts)<2:
                continue
            for i in range(len(ts)-1):
                ds.append([ts[i],ts[i+1],[1]])

        nds = []
        for i in range(len(ds)):
            id1 = random.randint(0,len(ds)-1)
            id2 = random.randint(0,1)
            nds.append([ds[i][0],ds[id1][id2],[0]])

        self.data = ds + nds

    def __len__(self):
        return len(self.data)

    def __getitem__(self,index):
        d = self.data[index]
        ids1 = self.tokenizer.encode(d[0][:50]).ids
        ids2 = self.tokenizer.encode(d[1][:50]).ids
        ids = ([2]+ids1+[3]+ids2+[3])[:103]

        padding_size = 103 - len(ids)
        token_type_ids = [0 for _ in range(len(ids1)+2)] +\
            [1 for _ in range(len(ids2)+1)]
        mask = np.random.random(len(ids))
        mask = (mask > 0.05).astype(np.int64)
        if padding_size > 0:
            mask = np.hstack((mask,np.ones(padding_size)))
            ids += [1 for _ in range(padding_size)]
            token_type_ids += [0 for _ in range(padding_size)]
        mask_ids = []
        for i in range(len(mask)):
            if mask[i]==1:
                mask_ids.append(ids[i])
            else:
                mask_ids.append(4)

        return np.array(ids,dtype=np.int64),np.array(token_type_ids,dtype=np.int64),np.array(mask_ids,dtype=np.int64),np.array(d[2],dtype=np.int64)

# %%
def pretrain():
    config = ModelConfig(device=torch.device("cuda"))
    config.load("./model_save/config.json")
    model = PretrainModel(config)
    data = PretrainDataset()
    loader = DataLoader(data,batch_size=20,shuffle=True)
    epoch = 20
    optimizer = optim.Adam(model.parameters(),lr=1e-4)
    step = 0
    pbar = tqdm(loader)
    for e in range(epoch):
        for ids,token_type_ids,mask_ids,ns in pbar:
            ids = ids.to(config.device)
            token_type_ids = token_type_ids.to(config.device)
            mask_ids = mask_ids.to(config.device)
            ns = ns.to(config.device)
            
            optimizer.zero_grad()
            loss = model(mask_ids,token_type_ids,ids,ns)
            loss.backward()
            optimizer.step()
            step += 1
            desc = "[{}/{}][{}][{}]".format(e+1,epoch,step,float(loss))
            pbar.set_description(desc)
            if step % 100 == 0:
                wmp,cls = model(mask_ids,token_type_ids)
                pids = torch.argmax(wmp,dim=2)
                # print(f"ids.size:{ids.size()}")
                # print(f"pids.size:{pids.size()}")
                for i in range(pids.size(0)):
                    s = data.tokenizer.decode(pids.detach().cpu().numpy()[i])
                    ori_s = data.tokenizer.decode(ids.detach().cpu().numpy()[i])
                    print("\n\n==[{}]==\n==[{}]==\n\n".format(s,ori_s))
            if step % 5000 == 0:
                torch.save(model.state_dict(),"./model_save/model_pretrain_{}.pt".format(step))
        torch.save(model.transformer.state_dict(),"./model_save/model_pretrain_done.pt")

# %%
pretrain()
# Out:
# 100%|██████████| 138/138 [00:00<00:00, 391090.51it/s]
# [1/20][27][6.906792163848877]: 100%|██████████| 27/27 [00:00<00:00, 55.51it/s]
# ==[##， ##， ##， ##， ##， ##，]==
# ==[因 ##嘱 ##其 ##静 ##心 ##养 ##病 ##， ##不 ##必 ##挂 ##念 ##营 ##务 ##， ##余 ##代 ##为 ##函 ##告 ##南 ##省 ##江 ##省 ##等 ##语 同 ##乡 ##京 ##官 ##如 ##故 ##， ##郑 ##莘 ##田 ##给 ##谏 ##服 ##阙 ##来 ##京 ##， ##梅 ##霖 ##生 ##病 ##势 ##沉 ##重 ##， ##深 ##为 ##可 ##虑]==
#
#
#
#
# ==[]==
# ==[且 ##望 ##诸 ##弟 ##分 ##此 ##重 ##任 ##， ##余 ##亦 ##欲 ##稍 ##稍 ##息 ##肩 ##， ##乃 ##不 ##得 ##一 ##售 ##， ##使 ##我 ##中 ##心 ##无 ##倚]==
#
#
#
#
# ==[]==
# ==[男 ##谨 ##禀 （ ##道 ##光 ##二 ##十 ##四 ##年 ##七 ##月 ##廿 ##日 ##）]==
#
#
#
#
# ==[]==
# ==[又 ##有 ##当 ##名 ##士 ##者 ##， ##鄙 ##科 ##名 ##为 ##粪 ##土 ##， ##或 ##好 ##作 ##诗 ##古 ##文 ##， ##或 ##好 ##讲 ##考 ##据 ##， ##或 ##好 ##谈 ##理 ##学 ##， ##嚣 ##嚣 ##然 ##自 ##以 ##为 ##压 ##倒 ##一 ##切 ##矣 吾 ##家 ##戏 ##言 ##戏 ##动 ##积 ##习 ##， ##明 ##年 ##喜 ##在 ##家 ##， ##当 ##与 ##两 ##先 ##生 ##尽 ##改 ##之]==
#
#
#
#
# ==[##，]==
# ==[切 ##己 ##体 ##察 ##， ##穷 ##其 ##理 ##， ##即 ##格 ##物 ##也 四 ##弟 ##九 ##弟 ##虽 ##不 ##长 ##进 ##， ##亦 ##不 ##自 ##满 ##， ##求 ##大 ##人 ##教 ##六 ##弟 ##， ##总 ##期 ##不 ##自 ##满 ##足 ##为 ##要]==
#
#
#
#
# ==[##， ##，]==
# ==[以 ##后 ##务 ##宜 ##力 ##除 ##此 ##病 ##， ##以 ##吴 ##（ ##木 ##云 ##） ##台 ##凌 ##荻 ##舟 ##为 ##眼 ##前 ##之 ##大 ##戒 凡 ##遇 ##牢 ##骚 ##欲 ##发 ##之 ##时 ##， ##则 ##反 ##躬 ##自 ##思 ##， ##吾 ##果 ##有 ##何 ##不 ##足 ##， ##而 ##蓄 ##此 ##不 ##平 ##之 ##气 ##， ##猛 ##然 ##内 ##省 ##， ##决 ##然 ##去 ##之]==
#
#
#
#
# ==[##， ##，]==
# ==[树 ##堂 ##极 ##为 ##虚 ##心 ##， ##爱 ##我 ##如 ##兄 ##弟 ##， ##敬 ##我 ##如 ##师 ##， ##将 ##来 ##必 ##有 ##所 ##成 但 ##人 ##事 ##太 ##多 ##， ##故 ##不 ##常 ##作 ##诗 ##； ##用 ##心 ##思 ##索 ##， ##则 ##无 ##时 ##敢 ##忘 ##之 ##耳]==
#
#
#
#
# ==[]==
# ==[吾 ##友 ##吴 ##竹 ##如 ##格 ##物 ##工 ##夫 ##颇 ##深 ##， ##一 ##事 ##一 ##物 ##， ##皆 ##求 ##其 ##理 倭 ##艮 ##峰 ##先 ##生 ##则 ##诚 ##意 ##工 ##夫 ##极 ##严 ##， ##每 ##日 ##有 ##日 ##课 ##册]==
#
#
#
#
# ==[##，]==
# ==[渠 ##已 ##醒 ##悟 ##， ##且 ##有 ##喜 ##色 因 ##嘱 ##其 ##静 ##心 ##养 ##病 ##， ##不 ##必 ##挂 ##念 ##营 ##务 ##， ##余 ##代 ##为 ##函 ##告 ##南 ##省 ##江 ##省 ##等 ##语]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[冯 ##树 ##堂 ##与 ##余 ##同 ##日 ##记 ##起 ##， ##亦 ##有 ##日 ##课 ##册 项 ##读 ##毕 ##《 ##书 ##经 ##》 ##， ##请 ##先 ##生 ##再 ##将 ##《 ##诗 ##经 ##》 ##点 ##读 ##一 ##遍 ##， ##夜 ##间 ##讲 ##《 ##纲 ##鉴 ##》 ##正 ##史 ##， ##约 ##已 ##讲 ##至 ##秦 ##商 ##鞅 ##开 ##阡 ##陌]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[尽 ##其 ##慎 ##独 ##之 ##严 ##， ##虽 ##妄 ##念 ##偶 ##动 ##， ##必 ##即 ##时 ##克 ##治 ##， ##而 ##著 ##之 ##于 ##书 ##， ##故 ##所 ##卖 ##之 ##书 ##， ##句 ##句 ##皆 ##切 ##身 ##之 ##要 ##药 弟 ##性 ##褊 ##急 ##似 ##余 ##， ##恐 ##拂 ##郁 ##或 ##生 ##肝 ##疾 ##， ##幸 ##息 ##心 ##忍 ##耐 ##为 ##要 ##！ ##兹 ##趁 ##便 ##； ##寄 ##一 ##缄 ##， ##托 ##黄 ##宅 ##转 ##遁 ##， ##弟 ##接 ##到 ##后 ##， ##弟 ##接 ##到 ##后 ##， ##望 ##（ ##上]==
#
#
#
#
# ==[##，]==
# ==[又 ##有 ##当 ##名 ##士 ##者 ##， ##鄙 ##科 ##名 ##为 ##粪 ##土 ##， ##或 ##好 ##作 ##诗 ##古 ##文 ##， ##或 ##好 ##讲 ##考 ##据 ##， ##或 ##好 ##谈 ##理 ##学 ##， ##嚣 ##嚣 ##然 ##自 ##以 ##为 ##压 ##倒 ##一 ##切 ##矣 自 ##识 ##者 ##观 ##之 ##， ##彼 ##其 ##所 ##造 ##曾 ##无 ##几 ##何 ##， ##亦 ##足 ##发 ##一 ##冷 ##笑 ##而 ##已]==
#
#
#
#
# ==[##， ##， ##， ##，]==
# ==[邓 ##先 ##生 ##品 ##学 ##极 ##好 ##， ##甲 ##三 ##八 ##股 ##文 ##有 ##长 ##进 ##， ##亦 ##山 ##先 ##生 ##亦 ##请 ##邓 ##改 ##文 切 ##己 ##体 ##察 ##， ##穷 ##其 ##理 ##， ##即 ##格 ##物 ##也]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##，]==
# ==[叔 ##父 ##之 ##病 ##， ##男 ##累 ##求 ##详 ##信 ##直 ##告 ##， ##至 ##今 ##未 ##得 ##， ##实 ##不 ##放 ##心 不 ##可 ##又 ##想 ##读 ##书 ##， ##又 ##想 ##中 ##举 ##， ##又 ##想 ##作 ##州 ##县 ##， ##纷 ##纷 ##扰 ##扰 ##， ##千 ##头 ##万 ##绪 ##， ##将 ##来 ##又 ##蹈 ##我 ##之 ##覆 ##辙 ##， ##百 ##无 ##一 ##成 ##， ##悔 ##之 ##晚 ##矣]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##，]==
# ==[吾 ##尝 ##见 ##朋 ##友 ##不 ##中 ##牢 ##骚 ##太 ##甚 ##者 ##， ##其 ##后 ##必 ##多 ##抑 ##塞 ##① ##， ##如 ##吴 ##（ ##木 ##云 ##） ##台 ##凌 ##荻 ##舟 ##之 ##流 ##， ##指 ##不 ##胜 ##屈 盖 ##无 ##故 ##而 ##怨 ##天 ##， ##则 ##天 ##必 ##不 ##许 ##， ##无 ##故 ##而 ##尤 ##天 ##， ##则 ##天 ##必 ##不 ##许 ##， ##无 ##故 ##而 ##尤 ##人 ##， ##则 ##人 ##必 ##不 ##服 ##， ##感 ##应 ##之 ##理 ##， ##自 ##然 ##随 ##之]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##，]==
# ==[男 ##虽 ##终 ##身 ##在 ##礼 ##部 ##衙 ##门 ##， ##为 ##国 ##家 ##办 ##照 ##例 ##之 ##事 ##， ##不 ##苟 ##不 ##懈 ##， ##尽 ##就 ##条 ##理 ##， ##亦 ##所 ##深 ##愿 ##也 广 ##东 ##之 ##事 ##， ##四 ##月 ##十 ##八 ##日 ##得 ##捷 ##音 ##， ##兹 ##将 ##抄 ##报 ##付 ##回]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[特 ##兄 ##自 ##近 ##年 ##以 ##来 ##， ##事 ##务 ##日 ##多 ##， ##精 ##神 ##日 ##耗 ##， ##常 ##常 ##望 ##诸 ##弟 ##有 ##继 ##起 ##者 ##， ##长 ##住 ##京 ##城 ##， ##为 ##我 ##助 ##一 ##臂 ##之 ##力 六 ##弟 ##今 ##年 ##正 ##月 ##信 ##， ##欲 ##从 ##罗 ##维 ##山 ##处 ##附 ##来 ##， ##男 ##甚 ##喜 ##之 ##！ ##后 ##来 ##信 ##绝 ##不 ##提 ##及 ##， ##不 ##知 ##何 ##故 ##？ ##所 ##付 ##来 ##京 ##之 ##文 ##， ##殊 ##不 ##甚 ##好]==
#
#
#
#
# ==[##，]==
# ==[吾 ##为 ##其 ##始 ##， ##弟 ##善 ##其 ##终 ##， ##实 ##有 ##厚 ##望 物 ##者 ##何 ##？ ##即 ##所 ##谓 ##本 ##末 ##之 ##物 ##也]==
#
#
#
#
# ==[]==
# ==[究 ##其 ##敬 ##身 ##之 ##理 ##， ##又 ##博 ##究 ##其 ##立 ##齐 ##坐 ##尸 ##以 ##敬 ##身 ##之 ##理 ##， ##即 ##格 ##物 ##也 如 ##事 ##亲 ##定 ##省 ##， ##物 ##也]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##，]==
# ==[男 ##谨 ##禀 ##， ##即 ##请 ##母 ##亲 ##大 ##人 ##万 ##福 ##金 ##安 王 ##衡 ##臣 ##于 ##闰 ##月 ##初 ##九 ##引 ##见 ##， ##以 ##知 ##县 ##用 ##， ##后 ##于 ##月 ##底 ##搬 ##寓 ##下 ##洼 ##一 ##庙 ##中 ##， ##竟 ##于 ##九 ##月 ##初 ##二 ##夜 ##无 ##故 ##遽 ##卒]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##不 ##， ##， ##不 ##， ##， ##，]==
# ==[吾 ##为 ##其 ##始 ##， ##弟 ##善 ##其 ##终 ##， ##实 ##有 ##厚 ##望 若 ##稍 ##参 ##以 ##客 ##气 ##， ##将 ##以 ##鼓 ##志 ##， ##则 ##不 ##能 ##为 ##我 ##增 ##气 ##也]==
#
#
#
#
# ==[##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[吴 ##竹 ##如 ##窦 ##兰 ##泉 ##之 ##精 ##义 ##， ##一 ##言 ##一 ##事 ##， ##必 ##求 ##至 ##是 吴 ##子 ##序 ##邵 ##慧 ##西 ##之 ##谈 ##经 ##， ##深 ##思 ##有 ##辨]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##不 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##， ##之]==
# ==[树 ##堂 ##极 ##为 ##虚 ##心 ##， ##爱 ##我 ##如 ##兄 ##弟 ##， ##敬 ##我 ##如 ##师 ##， ##将 ##来 ##必 ##有 ##所 ##成 但 ##人 ##事 ##太 ##多 ##， ##故 ##不 ##常 ##作 ##诗 ##； ##用 ##心 ##思 ##索 ##， ##则 ##无 ##时 ##敢 ##忘 ##之 ##耳]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之]==
# ==[沅 ##弟 ##书 ##中 ##， ##言 ##温 ##弟 ##之 ##文 ##， ##典 ##丽 ##鹬 ##皇 ##， ##亦 ##尔 ##被 ##抑 ##， ##不 ##知 ##我 ##诸 ##弟 ##中 ##半 ##来 ##科 ##名 ##， ##究 ##竟 ##何 ##如 ##？ ##以 ##祖 ##宗 ##之 ##积 ##累 ##， ##及 ##父 ##亲 ##叔 ##父 ##之]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##不 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##不 ##， ##，]==
# ==[弟 ##宜 ##以 ##李 ##迪 ##庵 ##为 ##法 ##， ##不 ##慌 ##不 ##忙 ##， ##盈 ##科 ##后 ##进 ##， ##到 ##八 ##九 ##个 ##月 ##后 ##， ##必 ##有 ##一 ##番 ##回 ##甘 ##滋 ##味 ##出 ##来 纪 ##云 ##对 ##郭 ##雨 ##三 ##之 ##女 ##， ##虽 ##未 ##订 ##盟 ##， ##而 ##彼 ##此 ##呼 ##亲 ##家 ##， ##称 ##姻 ##弟 ##， ##往 ##来 ##亲 ##密 ##， ##断 ##不 ##改 ##移]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##，]==
# ==[弟 ##章 ##既 ##得 ##楚 ##局 ##每 ##月 ##六 ##千 ##， ##又 ##得 ##江 ##局 ##月 ##二 ##三 ##千 ##， ##便 ##是 ##极 ##好 ##境 ##遇 余 ##将 ##弟 ##已 ##赴 ##营 ##， ##省 ##城 ##可 ##筹 ##半 ##饷 ##等 ##事 ##， ##告 ##之 ##四 ##五 ##次]==
#
#
#
#
# ==[##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[营 ##中 ##哨 ##队 ##请 ##人 ##气 ##尚 ##完 ##固 ##否 ##？ ##下 ##次 ##祈 ##书 ##及 我 ##县 ##之 ##亏 ##， ##亏 ##于 ##官 ##者 ##半 ##， ##亏 ##于 ##书 ##吏 ##者 ##半 ##， ##而 ##民 ##则 ##无 ##辜 ##也]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##不 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##不 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[男 ##恐 ##大 ##发 ##， ##则 ##不 ##能 ##入 ##见 ##， ##故 ##不 ##敢 ##用 ##心 ##， ##谨 ##守 ##大 ##人 ##保 ##养 ##身 ##体 ##之 ##训 ##， ##隔 ##一 ##日 ##至 ##衙 ##门 ##办 ##公 ##事 ##， ##余 ##则 ##在 ##家 ##不 ##妄 ##出 ##门 现 ##在 ##衙 ##门 ##诸 ##事 ##， ##男 ##俱 ##已 ##熟 ##悉 ##， ##各 ##司 ##官 ##于 ##男 ##皆 ##甚 ##佩 ##服 ##， ##上 ##下 ##水 ##乳 ##俱 ##融 ##， ##同 ##寅 ##亦 ##极 ##协 ##和]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##，]==
# ==[每 ##日 ##作 ##事 ##愈 ##多 ##， ##则 ##夜 ##间 ##临 ##睡 ##愈 ##快 ##活 若 ##存 ##一 ##爱 ##惜 ##精 ##神 ##的 ##意 ##思 ##， ##将 ##前 ##将 ##却 ##， ##奄 ##奄 ##无 ##气 ##， ##决 ##难 ##成 ##事 ##— ##— ##凡 ##此 ##， ##皆 ##因 ##弟 ##兴 ##会 ##索 ##然 ##之 ##言 ##而 ##切 ##戒 ##之 ##者 ##也]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[余 ##自 ##十 ##月 ##初 ##一 ##日 ##起 ##， ##亦 ##照 ##艮 ##峰 ##样 ##， ##每 ##日 ##一 ##念 ##一 ##事 ##， ##皆 ##写 ##之 ##于 ##册 ##， ##以 ##便 ##触 ##目 ##克 ##治 ##， ##亦 ##写 ##楷 ##书 若 ##调 ##理 ##得 ##宜 ##， ##半 ##月 ##当 ##可 ##痊 ##愈 ##， ##复 ##原 ##则 ##尚 ##不 ##易 ##易]==
#
#
#
#
# ==[##， ##不 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##不 ##， ##， ##， ##，]==
# ==[现 ##在 ##衙 ##门 ##诸 ##事 ##， ##男 ##俱 ##已 ##熟 ##悉 ##， ##各 ##司 ##官 ##于 ##男 ##皆 ##甚 ##佩 ##服 ##， ##上 ##下 ##水 ##乳 ##俱 ##融 ##， ##同 ##寅 ##亦 ##极 ##协 ##和 男 ##虽 ##终 ##身 ##在 ##礼 ##部 ##衙 ##门 ##， ##为 ##国 ##家 ##办 ##照 ##例 ##之 ##事 ##， ##不 ##苟 ##不 ##懈 ##， ##尽 ##就 ##条 ##理 ##， ##亦 ##所 ##深 ##愿 ##也]==
#
#
#
#
# ==[##， ##，]==
# ==[才 ##报 ##于 ##器 ##， ##良 ##为 ##知 ##言]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##不]==
# ==[昔 ##某 ##官 ##有 ##一 ##门 ##生 ##为 ##本 ##省 ##学 ##政 ##， ##托 ##以 ##两 ##孙 ##， ##当 ##面 ##拜 ##为 ##门 ##生 后 ##其 ##两 ##孙 ##岁 ##考 ##临 ##场 ##大 ##病 ##， ##科 ##考 ##丁 ##艰 ##， ##竟 ##不 ##入 ##学]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##不 ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[尽 ##其 ##慎 ##独 ##之 ##严 ##， ##虽 ##妄 ##念 ##偶 ##动 ##， ##必 ##即 ##时 ##克 ##治 ##， ##而 ##著 ##之 ##于 ##书 ##， ##故 ##所 ##卖 ##之 ##书 ##， ##句 ##句 ##皆 ##切 ##身 ##之 ##要 ##药 弟 ##性 ##褊 ##急 ##似 ##余 ##， ##恐 ##拂 ##郁 ##或 ##生 ##肝 ##疾 ##， ##幸 ##息 ##心 ##忍 ##耐 ##为 ##要 ##！ ##兹 ##趁 ##便 ##； ##寄 ##一 ##缄 ##， ##托 ##黄 ##宅 ##转 ##遁 ##， ##弟 ##接 ##到 ##后 ##， ##弟 ##接 ##到 ##后 ##， ##望 ##（ ##上]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##不 ##，]==
# ==[何 ##必 ##择 ##地 ##， ##何 ##必 ##择 ##时 ##， ##但 ##自 ##问 ##立 ##志 ##之 ##真 ##不 ##真 ##耳]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[故 ##吾 ##人 ##用 ##功 ##， ##力 ##除 ##傲 ##气 ##， ##力 ##戒 ##自 ##满 ##， ##毋 ##为 ##人 ##所 ##冷 ##笑 ##， ##乃 ##有 ##进 ##步 ##也 人 ##而 ##无 ##恒 ##， ##终 ##身 ##一 ##无 ##所 ##成 ##， ##我 ##生 ##平 ##坐 ##犯 ##无 ##恒 ##的 ##弊 ##病 ##， ##实 ##在 ##受 ##害 ##不 ##校 ##当 ##翰 ##林 ##时 ##， ##应 ##留 ##心 ##诗 ##字 ##， ##则 ##好 ##涉 ##猎 ##他 ##书 ##， ##以 ##纷 ##其]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##不 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##不 ##， ##， ##之 ##， ##， ##， ##， ##不 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[在 ##外 ##带 ##兵 ##， ##又 ##不 ##能 ##竭 ##力 ##专 ##治 ##军 ##事 ##， ##或 ##读 ##书 ##写 ##字 ##以 ##乱 ##其 ##志 ##意 郁 ##滋 ##堂 ##如 ##此 ##之 ##好 ##， ##余 ##实 ##不 ##胜 ##感 ##激 ##！ ##在 ##长 ##沙 ##时 ##， ##曾 ##未 ##道 ##及 ##彭 ##山 ##屺]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##， ##， ##不 ##， ##， ##， ##， ##， ##，]==
# ==[今 ##年 ##新 ##进 ##士 ##龙 ##翰 ##臣 ##得 ##状 ##元 ##， ##系 ##前 ##任 ##湘 ##乡 ##知 ##县 ##见 ##田 ##年 ##伯 ##之 ##世 ##兄 ##， ##同 ##乡 ##六 ##人 ##， ##得 ##四 ##庶 ##常 ##， ##两 ##知 ##县 ##， ##复 ##试 ##单 ##已 ##于 ##闰 ##三 ##月 ##十 男 ##虽 ##终 ##身 ##在 ##礼 ##部 ##衙 ##门 ##， ##为 ##国 ##家 ##办 ##照 ##例 ##之 ##事 ##， ##不 ##苟 ##不 ##懈 ##， ##尽 ##就 ##条 ##理 ##， ##亦 ##所 ##深 ##愿 ##也]==
#
#
#
#
# ==[##， ##， ##， ##， ##之 ##， ##，]==
# ==[格 ##物 ##， ##致 ##知 ##之 ##事 ##也 诚 ##意 ##， ##力 ##行 ##之 ##事 ##也]==
#
#
#
#
# ==[##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##， ##，]==
# ==[项 ##接 ##来 ##缄 ##， ##又 ##得 ##所 ##寄 ##吉 ##安 ##一 ##缄 ##， ##具 ##悉 ##一 ##切 朱 ##太 ##守 ##来 ##我 ##县 ##， ##王 ##刘 ##蒋 ##唐 ##往 ##陪 ##， ##而 ##弟 ##不 ##往 ##宜 ##其 ##见 ##怪]==
#
#
#
#
# ==[##不 ##有 ##之 ##不 ##有 ##也 ##不 ##一 ##自 ##， ##不 ##， ##则 ##， ##， ##， ##， ##日 ##不 ##， ##不 ##， ##， ##， ##， ##之 ##， ##， ##之 ##不 ##弟 ##之 ##， ##之 ##之 ##不]==
# ==[又 ##余 ##有 ##浙 ##盐 ##赢 ##馀 ##万 ##五 ##千 ##两 ##在 ##江 ##省 ##， ##昨 ##盐 ##局 ##专 ##丁 ##前 ##来 ##禀 ##沟 ##， ##余 ##嘱 ##其 ##解 ##交 ##藩 ##库 ##充 ##饷 ##， ##将 ##来 ##此 ##款 ##或 ##可 ##酌 ##解 ##弟 ##营 ##， ##但 ##弟 ##不 ##宜]==
#
#
#
#
# ==[##之 ##不 ##弟 ##， ##， ##一 ##之 ##， ##， ##则 ##一 ##， ##不 ##， ##则 ##无]==
# ==[万 ##望 ##温 ##弟 ##再 ##三 ##细 ##想 ##， ##勿 ##以 ##吾 ##言 ##为 ##老 ##生 ##常 ##谈 ##， ##不 ##直 ##一 ##哂 ##② ##也]==
#
#
#
#
# ==[##弟 ##之 ##， ##， ##之 ##之 ##弟 ##之 ##， ##， ##， ##不 ##不 ##， ##， ##不 ##， ##之 ##， ##不 ##不 ##， ##， ##之 ##之 ##， ##， ##之 ##， ##， ##不 ##弟 ##之 ##之 ##之 ##之 ##之 ##， ##之 ##， ##之 ##之]==
# ==[沅 ##弟 ##书 ##中 ##， ##言 ##温 ##弟 ##之 ##文 ##， ##典 ##丽 ##鹬 ##皇 ##， ##亦 ##尔 ##被 ##抑 ##， ##不 ##知 ##我 ##诸 ##弟 ##中 ##半 ##来 ##科 ##名 ##， ##究 ##竟 ##何 ##如 ##？ ##以 ##祖 ##宗 ##之 ##积 ##累 ##， ##及 ##父 ##亲 ##叔 ##父 ##之]==
#
#
#
#
# ==[##， ##， ##， ##， ##之 ##， ##之 ##， ##， ##， ##， ##， ##之 ##， ##， ##之 ##之 ##不 ##， ##可 ##， ##不 ##， ##， ##之 ##， ##， ##之 ##， ##之 ##， ##不 ##， ##之 ##， ##自 ##不 ##， ##不 ##之 ##， ##， ##不 ##有 ##， ##， ##之 ##一 ##之 ##之 ##， ##不 ##， ##， ##， ##， ##， ##，]==
# ==[且 ##苟 ##能 ##发 ##奋 ##自 ##立 ##， ##则 ##家 ##塾 ##可 ##读 ##书 ##， ##即 ##旷 ##野 ##之 ##地 ##， ##热 ##闹 ##之 ##场 ##， ##亦 ##可 ##读 ##书 ##， ##负 ##薪 ##牧 ##豕 ##， ##皆 ##可 ##读 ##书 余 ##自 ##十 ##月 ##初 ##一 ##起 ##记 ##日 ##课 ##， ##念 ##念 ##欲 ##改 ##过 ##自 ##新 ##； ##思 ##从 ##前 ##与 ##小 ##珊 ##有 ##隙 ##， ##实 ##是 ##一 ##朝 ##之 ##忿 ##， ##不 ##近 ##人 ##情 ##， ##即 ##欲 ##登 ##门 ##谢 ##罪]==
#
#
#
#
# ==[##， ##不 ##， ##， ##则 ##之 ##之 ##日 ##， ##则 ##， ##， ##不 ##不 ##， ##有 ##之 ##之]==
# ==[弟 ##试 ##留 ##心 ##此 ##事 ##， ##亦 ##练 ##理 ##之 ##一 ##端 ##也 至 ##规 ##模 ##宜 ##大 ##， ##弟 ##亦 ##讲 ##求 ##及 ##之]==
#
#
#
#
# ==[##， ##之 ##不 ##， ##不 ##之 ##也 ##， ##， ##， ##， ##， ##之 ##则 ##自 ##， ##， ##不 ##之 ##不 ##则 ##不 ##， ##， ##， ##， ##之]==
# ==[谨 ##此 ##禀 ##闻 ##， ##余 ##详 ##与 ##诸 ##弟 ##书 ##中 若 ##稍 ##参 ##以 ##客 ##气 ##， ##将 ##以 ##鼓 ##志 ##， ##则 ##不 ##能 ##为 ##我 ##增 ##气 ##也]==
#
#
#
#
# ==[##日 ##之 ##有 ##， ##， ##， ##之 ##不 ##也 ##， ##不 ##， ##之 ##， ##不 ##之 ##则 ##不]==
# ==[厚 ##庵 ##放 ##闽 ##中 ##提 ##督 ##， ##已 ##赴 ##金 ##陵 ##会 ##剿 ##， ##准 ##其 ##专 ##招 ##奏 ##事 九 ##江 ##亦 ##即 ##日 ##可 ##复]==
#
#
#
#
# ==[##， ##不 ##， ##， ##， ##不 ##不 ##不 ##之 ##， ##不 ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##之 ##之 ##之 ##之 ##之 ##， ##， ##， ##， ##， ##之 ##之 ##， ##， ##无 ##， ##之 ##不 ##之 ##， ##不 ##不 ##之 ##， ##之 ##不 ##， ##， ##之 ##， ##， ##， ##不 ##不 ##，]==
# ==[甲 ##三 ##读 ##《 ##尔 ##雅 ##》 ##， ##每 ##日 ##二 ##十 ##余 ##字 ##， ##颇 ##肯 ##率 ##教 六 ##弟 ##今 ##年 ##正 ##月 ##信 ##， ##欲 ##从 ##罗 ##维 ##山 ##处 ##附 ##来 ##， ##男 ##甚 ##喜 ##之 ##！ ##后 ##来 ##信 ##绝 ##不 ##提 ##及 ##， ##不 ##知 ##何 ##故 ##？ ##所 ##付 ##来 ##京 ##之 ##文 ##， ##殊 ##不 ##甚 ##好]==
#
#
#
#
# ==[##弟 ##， ##有 ##， ##， ##， ##， ##， ##之 ##， ##不 ##， ##， ##， ##， ##不 ##， ##不 ##， ##， ##， ##， ##不 ##之 ##， ##不 ##， ##， ##， ##， ##， ##， ##则 ##之 ##， ##， ##， ##弟 ##， ##， ##， ##， ##人 ##则 ##， ##， ##不 ##， ##则 ##， ##不 ##， ##，]==
# ==[九 ##弟 ##功 ##课 ##有 ##常 ##， ##《 ##礼 ##记 ##》 ##九 ##本 ##已 ##点 ##完 ##， ##《 ##鉴 ##》 ##已 ##看 ##至 ##《 ##三 ##国 ##》 ##， ##《 ##斯 ##文 ##精 ##粹 ##》 ##诗 ##文 ##， ##各 ##已 ##读 ##半 ##本 ##， ##诗 ##略 ##进 ##功 ##， ##文 ##章 若 ##调 ##理 ##得 ##宜 ##， ##半 ##月 ##当 ##可 ##痊 ##愈 ##， ##复 ##原 ##则 ##尚 ##不 ##易 ##易]==
#
#
#
#
# ==[##日 ##之 ##， ##， ##， ##， ##则 ##之 ##， ##， ##之 ##则 ##之 ##， ##则 ##， ##， ##， ##， ##则 ##， ##之 ##不 ##， ##， ##， ##之 ##， ##之 ##一 ##， ##亦 ##， ##不 ##， ##， ##之 ##， ##， ##， ##不 ##无 ##， ##之 ##不 ##， ##， ##也]==
# ==[昨 ##廿 ##七 ##日 ##接 ##信 ##， ##畅 ##快 ##之 ##至 ##， ##以 ##信 ##多 ##而 ##处 ##处 ##详 ##明 ##也 公 ##车 ##来 ##， ##兑 ##六 ##七 ##十 ##金 ##， ##为 ##送 ##亲 ##族 ##之 ##用 ##， ##亦 ##必 ##不 ##可 ##缓 ##， ##但 ##京 ##寓 ##近 ##极 ##艰 ##窘 ##， ##此 ##外 ##不 ##可 ##再 ##兑 ##也]==
#
#
#
#
# ==[##之 ##， ##， ##也 ##不 ##， ##， ##， ##则 ##， ##， ##， ##有 ##，]==
# ==[湖 ##南 ##榜 ##发 ##， ##吾 ##邑 ##竟 ##不 ##中 ##一 ##人 天 ##地 ##万 ##物 ##， ##皆 ##物 ##也]==
#
#
#
#
# ==[##不 ##日 ##， ##则 ##不 ##有 ##十 ##， ##不 ##， ##之 ##不 ##， ##之 ##， ##， ##， ##， ##， ##不 ##， ##， ##之 ##之 ##之 ##， ##之 ##不 ##， ##之 ##之 ##， ##之 ##之 ##也 ##之 ##之 ##不]==
# ==[十 ##二 ##日 ##正 ##七 ##、 ##有 ##十 ##归 ##， ##接 ##弟 ##信 ##， ##备 ##悉 ##一 ##切 定 ##湘 ##营 ##既 ##至 ##三 ##曲 ##滩 ##， ##其 ##营 ##官 ##成 ##章 ##鉴 ##亦 ##武 ##弁 ##中 ##之 ##不 ##可 ##多 ##得 ##者 ##， ##弟 ##可 ##与 ##之 ##款 ##接]==
#
#
#
#
# ==[##不 ##有 ##不 ##不 ##， ##， ##， ##有 ##， ##， ##， ##， ##， ##， ##， ##， ##不 ##不 ##不 ##也 ##之 ##， ##不 ##， ##， ##一 ##， ##， ##之 ##， ##， ##， ##， ##， ##不 ##之 ##， ##之 ##一 ##之 ##也 ##不 ##， ##之]==
# ==[冯 ##树 ##堂 ##与 ##余 ##同 ##日 ##记 ##起 ##， ##亦 ##有 ##日 ##课 ##册 项 ##读 ##毕 ##《 ##书 ##经 ##》 ##， ##请 ##先 ##生 ##再 ##将 ##《 ##诗 ##经 ##》 ##点 ##读 ##一 ##遍 ##， ##夜 ##间 ##讲 ##《 ##纲 ##鉴 ##》 ##正 ##史 ##， ##约 ##已 ##讲 ##至 ##秦 ##商 ##鞅 ##开 ##阡 ##陌]==
#
#
#
#
# ==[##之 ##不 ##不 ##不 ##， ##， ##之 ##， ##之 ##之 ##， ##， ##， ##， ##， ##有 ##有 ##之 ##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##不 ##， ##之 ##之 ##之 ##不 ##， ##， ##， ##， ##，]==
# ==[四 ##弟 ##七 ##夕 ##诗 ##甚 ##佳 ##， ##已 ##详 ##批 ##诗 ##后 ##； ##从 ##此 ##多 ##作 ##诗 ##亦 ##甚 ##好 ##， ##但 ##须 ##有 ##志 ##有 ##恒 ##， ##乃 ##有 ##成 ##就 ##耳 弟 ##章 ##既 ##得 ##楚 ##局 ##每 ##月 ##六 ##千 ##， ##又 ##得 ##江 ##局 ##月 ##二 ##三 ##千 ##， ##便 ##是 ##极 ##好 ##境 ##遇]==
#
#
#
#
# ==[##， ##日 ##不 ##， ##不 ##， ##， ##， ##也 ##不 ##， ##自 ##， ##， ##之 ##， ##， ##， ##， ##之 ##不 ##， ##则 ##， ##， ##， ##之 ##， ##亦 ##， ##之 ##， ##， ##之 ##， ##， ##， ##弟 ##不 ##不 ##， ##之 ##， ##也 ##之 ##， ##， ##之]==
# ==[至 ##于 ##功 ##名 ##富 ##贵 ##， ##悉 ##由 ##命 ##走 ##， ##丝 ##毫 ##不 ##能 ##自 ##主 凡 ##遇 ##牢 ##骚 ##欲 ##发 ##之 ##时 ##， ##则 ##反 ##躬 ##自 ##思 ##， ##吾 ##果 ##有 ##何 ##不 ##足 ##， ##而 ##蓄 ##此 ##不 ##平 ##之 ##气 ##， ##猛 ##然 ##内 ##省 ##， ##决 ##然 ##去 ##之]==
#
#
#
#
# ==[##之 ##， ##之 ##皆 ##， ##， ##， ##之 ##不 ##之 ##有 ##， ##， ##， ##其 ##则 ##不 ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##， ##之]==
# ==[弟 ##之 ##综 ##理 ##密 ##微 ##， ##精 ##力 ##较 ##胜 ##于 ##我 军 ##中 ##器 ##械 ##， ##其 ##略 ##精 ##者 ##， ##宜 ##另 ##立 ##一 ##簿 ##， ##亲 ##自 ##记 ##注 ##， ##择 ##人 ##而 ##授 ##之]==
#
#
#
#
# ==[##， ##， ##， ##之 ##， ##， ##， ##， ##， ##， ##， ##之]==
# ==[黄 ##子 ##春 ##官 ##声 ##及 ##好 ##， ##听 ##讼 ##勤 ##明 ##， ##人 ##皆 ##畏 ##之]==
#
#
#
#
# ==[##无 ##， ##则 ##之 ##， ##则 ##日 ##不 ##， ##不 ##不 ##不 ##， ##则 ##不 ##不 ##， ##， ##， ##， ##， ##， ##不 ##， ##， ##之 ##， ##， ##之 ##之 ##， ##则 ##， ##也 ##， ##不 ##， ##之 ##， ##， ##， ##， ##， ##之 ##， ##，]==
# ==[盖 ##无 ##故 ##而 ##怨 ##天 ##， ##则 ##天 ##必 ##不 ##许 ##， ##无 ##故 ##而 ##尤 ##天 ##， ##则 ##天 ##必 ##不 ##许 ##， ##无 ##故 ##而 ##尤 ##人 ##， ##则 ##人 ##必 ##不 ##服 ##， ##感 ##应 ##之 ##理 ##， ##自 ##然 ##随 ##之 惟 ##损 ##银 ##弥 ##亏 ##， ##则 ##不 ##宜 ##操 ##之 ##太 ##急 ##， ##须 ##人 ##人 ##愿 ##捐 ##乃 ##可]==
#
#
#
#
# ==[##不 ##之 ##， ##， ##弟]==
# ==[嗣 ##后 ##弟 ##于 ##县 ##城 ##省 ##城 ##， ##均 ##不 ##宜 ##多 ##去]==
#
#
#
#
# ==[##则 ##人 ##， ##有 ##之 ##十 ##则 ##， ##， ##不 ##， ##， ##之 ##， ##， ##， ##不 ##， ##， ##， ##之 ##， ##之 ##， ##之 ##之 ##不 ##可 ##之 ##也 ##不 ##， ##之 ##不 ##之]==
# ==[公 ##车 ##来 ##， ##兑 ##六 ##七 ##十 ##金 ##， ##为 ##送 ##亲 ##族 ##之 ##用 ##， ##亦 ##必 ##不 ##可 ##缓 ##， ##但 ##京 ##寓 ##近 ##极 ##艰 ##窘 ##， ##此 ##外 ##不 ##可 ##再 ##兑 ##也 书 ##不 ##详 ##荆 ##余 ##俟 ##续 ##县]==
#
#
#
#
# ==[##日 ##者 ##日 ##， ##理 ##在 ##弟 ##， ##十 ##亦 ##弟 ##， ##则 ##， ##不 ##其 ##不 ##中 ##， ##则 ##日 ##人 ##， ##其 ##， ##也 ##， ##日 ##， ##其 ##有 ##， ##事 ##一 ##其 ##之 ##不 ##之 ##弟 ##， ##不 ##也 ##也]==
# ==[此 ##二 ##者 ##并 ##进 ##， ##下 ##学 ##在 ##此 ##， ##上 ##达 ##亦 ##在 ##此 吾 ##尝 ##见 ##朋 ##友 ##不 ##中 ##牢 ##骚 ##太 ##甚 ##者 ##， ##其 ##后 ##必 ##多 ##抑 ##塞 ##① ##， ##如 ##吴 ##（ ##木 ##云 ##） ##台 ##凌 ##荻 ##舟 ##之 ##流 ##， ##指 ##不 ##胜 ##屈]==
#
#
#
#
# ==[##也 ##者 ##， ##之 ##不 ##皆 ##之 ##可 ##， ##， ##不 ##， ##无 ##有 ##， ##已 ##， ##人 ##， ##不 ##之 ##来 ##有 ##， ##于 ##， ##弟 ##则 ##， ##大 ##， ##， ##则 ##不 ##， ##之 ##， ##， ##， ##不 ##有 ##则 ##之 ##， ##弟 ##大 ##， ##， ##无 ##， ##， ##之 ##不 ##， ##有 ##一 ##日 ##如 ##日 ##不 ##也 ##十 ##， ##， ##不 ##则 ##在 ##家 ##不 ##之]==
# ==[医 ##者 ##皆 ##言 ##心 ##亏 ##血 ##热 ##， ##故 ##不 ##能 ##养 ##肝 ##， ##热 ##极 ##生 ##风 ##， ##阳 ##气 ##上 ##肝 ##， ##故 ##见 ##于 ##头 ##面 男 ##恐 ##大 ##发 ##， ##则 ##不 ##能 ##入 ##见 ##， ##故 ##不 ##敢 ##用 ##心 ##， ##谨 ##守 ##大 ##人 ##保 ##养 ##身 ##体 ##之 ##训 ##， ##隔 ##一 ##日 ##至 ##衙 ##门 ##办 ##公 ##事 ##， ##余 ##则 ##在 ##家 ##不 ##妄 ##出 ##门]==
#
#
#
#
# ==[##不 ##之 ##弟 ##日 ##也 ##， ##， ##人 ##之 ##， ##， ##生 ##一 ##一 ##， ##不 ##一 ##则 ##无 ##也]==
# ==[万 ##望 ##温 ##弟 ##再 ##三 ##细 ##想 ##， ##勿 ##以 ##吾 ##言 ##为 ##老 ##生 ##常 ##谈 ##， ##不 ##直 ##一 ##哂 ##② ##也]==
#
#
#
#
# ==[##， ##日 ##十 ##日 ##则 ##， ##不 ##， ##不 ##， ##自 ##皆 ##自 ##， ##虽 ##为 ##， ##无 ##， ##实 ##自 ##日 ##之 ##弟 ##人 ##可 ##一 ##， ##， ##不 ##， ##则 ##， ##皆 ##来 ##有 ##， ##之 ##一 ##， ##， ##则 ##不 ##，]==
# ==[每 ##日 ##除 ##应 ##酬 ##外 ##， ##不 ##能 ##不 ##略 ##自 ##用 ##功 ##， ##虽 ##欲 ##节 ##劳 ##， ##实 ##难 ##再 ##节 凡 ##人 ##作 ##一 ##事 ##， ##便 ##须 ##全 ##副 ##精 ##神 ##注 ##在 ##此 ##一 ##事 ##， ##首 ##尾 ##不 ##懈]==
#
#
#
#
# ==[##则 ##之 ##则 ##不 ##生 ##则 ##有 ##也 ##不 ##之 ##， ##， ##日 ##有 ##日 ##自 ##， ##弟 ##于 ##也 ##， ##自 ##则 ##， ##之 ##， ##余 ##则 ##十 ##其 ##所 ##日 ##之 ##不 ##， ##也]==
# ==[倭 ##艮 ##峰 ##先 ##生 ##则 ##诚 ##意 ##工 ##夫 ##极 ##严 ##， ##每 ##日 ##有 ##日 ##课 ##册 六 ##弟 ##屈 ##于 ##小 ##试 ##， ##自 ##称 ##数 ##奇 ##， ##余 ##穷 ##笑 ##其 ##所 ##忧 ##之 ##不 ##大 ##也]==
#
#
#
#
# ==[##也 ##也 ##有 ##日 ##则 ##， ##日 ##， ##， ##其 ##皆 ##者 ##日 ##之 ##日 ##其 ##也 ##来 ##则 ##， ##大 ##， ##一 ##， ##有 ##则 ##已 ##十 ##， ##， ##也 ##不 ##， ##一 ##， ##人 ##之 ##而 ##有]==
# ==[数 ##年 ##后 ##两 ##孙 ##乃 ##皆 ##入 ##， ##其 ##长 ##者 ##仍 ##得 ##两 ##榜 日 ##来 ##京 ##寓 ##大 ##小 ##平 ##安 ##， ##癣 ##疾 ##又 ##已 ##微 ##发 ##， ##幸 ##不 ##为 ##害 ##， ##听 ##之 ##而 ##已]==
#
#
#
#
# ==[##有 ##弟 ##十 ##， ##所 ##， ##之 ##其 ##， ##不 ##十 ##日 ##已 ##则 ##有 ##一 ##， ##有 ##之 ##有 ##之 ##之 ##， ##弟 ##之 ##亦 ##弟 ##有 ##之 ##则 ##不 ##事 ##者 ##， ##也 ##， ##也 ##大 ##有 ##， ##之 ##日 ##不 ##， ##， ##者 ##则 ##不 ##之 ##之 ##也 ##不 ##， ##则 ##也 ##人 ##人 ##于 ##弟]==
# ==[接 ##弟 ##十 ##五 ##夜 ##所 ##发 ##之 ##信 ##， ##知 ##十 ##六 ##日 ##已 ##赴 ##吉 ##安 ##矣 ##， ##吉 ##字 ##中 ##营 ##尚 ##易 ##整 ##顿 ##否 ##？ ##古 ##之 ##成 ##大 ##事 ##者 ##， ##规 ##模 ##远 ##大 ##与 ##综 ##理 ##密 ##微 ##， ##二 ##者 ##阙 弟 ##之 ##综 ##理 ##密 ##微 ##， ##精 ##力 ##较 ##胜 ##于 ##我]==
#
#
#
#
# ==[##则 ##一 ##， ##自 ##， ##之 ##， ##， ##， ##则 ##一 ##自 ##， ##其 ##已 ##有 ##不 ##不 ##之 ##， ##日 ##有 ##弟 ##不 ##为 ##之 ##之 ##， ##之 ##之 ##也 ##则 ##， ##日 ##之 ##之 ##日 ##自 ##来 ##， ##则 ##之 ##十 ##则 ##， ##， ##日 ##一 ##也 ##之 ##不 ##， ##亦 ##不 ##可 ##人 ##， ##之 ##则 ##， ##十 ##， ##弟 ##之 ##， ##之 ##其 ##不 ##， ##日 ##， ##也]==
# ==[凡 ##遇 ##牢 ##骚 ##欲 ##发 ##之 ##时 ##， ##则 ##反 ##躬 ##自 ##思 ##， ##吾 ##果 ##有 ##何 ##不 ##足 ##， ##而 ##蓄 ##此 ##不 ##平 ##之 ##气 ##， ##猛 ##然 ##内 ##省 ##， ##决 ##然 ##去 ##之 公 ##车 ##来 ##， ##兑 ##六 ##七 ##十 ##金 ##， ##为 ##送 ##亲 ##族 ##之 ##用 ##， ##亦 ##必 ##不 ##可 ##缓 ##， ##但 ##京 ##寓 ##近 ##极 ##艰 ##窘 ##， ##此 ##外 ##不 ##可 ##再 ##兑 ##也]==
#
#
#
#
# ==[##， ##日 ##， ##也 ##之 ##， ##也 ##有 ##， ##一 ##不 ##所 ##无 ##， ##也 ##之 ##有 ##也]==
# ==[诚 ##意 ##， ##力 ##行 ##之 ##事 ##也 物 ##者 ##何 ##？ ##即 ##所 ##谓 ##本 ##末 ##之 ##物 ##也]==
#
#
#
#
# ==[##则 ##理 ##， ##则 ##无 ##， ##弟 ##一 ##， ##之 ##不 ##自 ##书 ##， ##其 ##弟 ##一 ##于 ##家 ##日]==
# ==[然 ##出 ##外 ##从 ##师 ##， ##则 ##无 ##甚 ##耽 ##搁 ##， ##若 ##出 ##夕 ##做 ##书 ##， ##其 ##耽 ##搁 ##更 ##甚 ##于 ##家 ##塾 ##矣]==
#
#
#
#
# ==[##也 ##也 ##， ##无 ##不 ##， ##也 ##日 ##弟 ##， ##日 ##， ##已 ##之 ##不 ##， ##之 ##大 ##而 ##无 ##日 ##， ##皆 ##， ##一 ##无 ##所 ##， ##， ##， ##， ##一 ##有 ##无 ##之 ##中 ##， ##则 ##， ##实 ##一 ##之 ##人 ##不 ##其 ##则 ##之 ##， ##， ##也 ##， ##不 ##则 ##， ##则 ##， ##之 ##则 ##则 ##不 ##， ##之 ##其]==
# ==[不 ##可 ##见 ##异 ##思 ##迁 ##， ##做 ##这 ##样 ##想 ##那 ##样 ##， ##坐 ##这 ##山 ##望 ##那 ##山 人 ##而 ##无 ##恒 ##， ##终 ##身 ##一 ##无 ##所 ##成 ##， ##我 ##生 ##平 ##坐 ##犯 ##无 ##恒 ##的 ##弊 ##病 ##， ##实 ##在 ##受 ##害 ##不 ##校 ##当 ##翰 ##林 ##时 ##， ##应 ##留 ##心 ##诗 ##字 ##， ##则 ##好 ##涉 ##猎 ##他 ##书 ##， ##以 ##纷 ##其]==
#
#
#
#
# ==[##有 ##则 ##也 ##也 ##事 ##不 ##之 ##日 ##日 ##， ##日 ##， ##自 ##也 ##， ##日 ##可 ##， ##， ##， ##则 ##之 ##中 ##则 ##人 ##， ##已 ##则 ##则 ##， ##则 ##， ##也 ##其 ##日 ##， ##事 ##事]==
# ==[下 ##游 ##镇 ##江 ##、 ##瓜 ##洲 ##同 ##日 ##克 ##夏 ##， ##金 ##陵 ##指 ##日 ##可 ##克 厚 ##庵 ##放 ##闽 ##中 ##提 ##督 ##， ##已 ##赴 ##金 ##陵 ##会 ##剿 ##， ##准 ##其 ##专 ##招 ##奏 ##事]==
#
#
#
#
# ==[##也 ##也 ##大 ##人 ##则 ##也 ##一 ##， ##自 ##弟 ##也 ##之 ##一 ##一 ##亦 ##， ##得 ##有 ##不]==
# ==[父 ##母 ##亲 ##大 ##人 ##万 ##福 ##金 ##安 吴 ##子 ##序 ##邵 ##慧 ##西 ##之 ##谈 ##经 ##， ##深 ##思 ##有 ##辨]==
#
#
#
#
# ==[##家 ##之 ##无 ##， ##， ##日 ##， ##自 ##弟 ##可 ##有 ##日 ##日 ##， ##已 ##弟 ##则 ##实 ##自 ##理 ##， ##不 ##则 ##则 ##日 ##则]==
# ==[吾 ##家 ##之 ##无 ##人 ##继 ##起 ##， ##诸 ##弟 ##犹 ##可 ##稍 ##宽 ##其 ##责 ##， ##温 ##弟 ##则 ##实 ##自 ##弃 ##， ##不 ##昨 ##尽 ##诿 ##其 ##咎 ##于 ##命 ##运]==
#
#
#
#
# ==[##则 ##于 ##， ##亦 ##有 ##不 ##之 ##， ##之 ##， ##无 ##无 ##， ##不 ##之 ##不 ##也 ##一 ##之 ##， ##可 ##与 ##， ##者 ##， ##人 ##事 ##人 ##， ##， ##不 ##一 ##可 ##不 ##弟 ##自 ##不 ##， ##也 ##， ##， ##无 ##一 ##有 ##则 ##之 ##理 ##，]==
# ==[余 ##于 ##诗 ##亦 ##有 ##工 ##夫 ##， ##恨 ##当 ##世 ##无 ##韩 ##昌 ##黎 ##及 ##苏 ##黄 ##一 ##辈 ##人 ##可 ##与 ##发 ##吾 ##狂 ##言 ##者 但 ##人 ##事 ##太 ##多 ##， ##故 ##不 ##常 ##作 ##诗 ##； ##用 ##心 ##思 ##索 ##， ##则 ##无 ##时 ##敢 ##忘 ##之 ##耳]==
#
#
#
#
# ==[##其 ##无 ##弟 ##之 ##弟 ##， ##又 ##之 ##不 ##其 ##则 ##无 ##之 ##无 ##以 ##无 ##， ##之 ##理 ##， ##日 ##有 ##也 ##日 ##生 ##， ##则 ##无 ##之 ##之 ##， ##大 ##， ##， ##则 ##， ##不 ##， ##不 ##中 ##一 ##弟 ##则]==
# ==[究 ##其 ##存 ##心 ##之 ##理 ##， ##又 ##博 ##究 ##其 ##省 ##察 ##涵 ##养 ##以 ##存 ##心 ##之 ##理 ##， ##即 ##格 ##物 ##也 余 ##生 ##平 ##坐 ##无 ##恒 ##流 ##弊 ##极 ##大 ##， ##今 ##老 ##矣 ##， ##不 ##能 ##不 ##教 ##诫 ##吾 ##弟 ##吾 ##子]==
#
#
#
#
# ==[##十 ##不 ##日 ##， ##亦 ##， ##其 ##之 ##日 ##家 ##也 ##， ##也 ##， ##父 ##不 ##， ##， ##日 ##日 ##之 ##， ##之 ##弟 ##之 ##有 ##不 ##自 ##弟 ##此 ##也 ##， ##， ##， ##亦 ##之 ##之 ##也 ##则 ##不 ##， ##也 ##不 ##， ##一 ##， ##， ##， ##一 ##有 ##无 ##之]==
# ==[四 ##月 ##十 ##四 ##日 ##， ##接 ##奉 ##父 ##亲 ##三 ##月 ##初 ##九 ##日 ##手 ##谕 ##， ##并 ##叔 ##父 ##大 ##人 ##贺 ##喜 ##手 ##示 ##， ##及 ##四 ##弟 ##家 ##书 且 ##望 ##诸 ##弟 ##分 ##此 ##重 ##任 ##， ##余 ##亦 ##欲 ##稍 ##稍 ##息 ##肩 ##， ##乃 ##不 ##得 ##一 ##售 ##， ##使 ##我 ##中 ##心 ##无 ##倚]==
#
#
#
#
# ==[##皆 ##， ##有 ##也 ##， ##有 ##， ##， ##大 ##之 ##， ##，]==
# ==[事 ##兄 ##随 ##行 ##， ##物 ##也 格 ##物 ##， ##致 ##知 ##之 ##事 ##也]==
#
#
#
#
# ==[##之 ##理 ##皆 ##不 ##， ##皆 ##也 ##也 ##之 ##于 ##， ##之 ##则 ##也 ##自 ##之 ##之 ##， ##日 ##日 ##不 ##， ##亦 ##不 ##也]==
# ==[弟 ##之 ##综 ##理 ##密 ##微 ##， ##精 ##力 ##较 ##胜 ##于 ##我 冯 ##树 ##堂 ##陈 ##岱 ##云 ##之 ##立 ##志 ##， ##汲 ##汲 ##不 ##逞 ##， ##亦 ##良 ##友 ##也]==
#
#
#
#
# ==[##则 ##于 ##亦 ##有 ##不 ##有 ##， ##之 ##一 ##无 ##自 ##， ##不 ##之 ##也 ##一 ##之 ##， ##可 ##与 ##， ##， ##则 ##事 ##， ##则 ##实 ##日 ##无 ##日 ##也 ##弟 ##也 ##， ##则 ##一 ##也 ##之 ##日 ##也]==
# ==[余 ##于 ##诗 ##亦 ##有 ##工 ##夫 ##， ##恨 ##当 ##世 ##无 ##韩 ##昌 ##黎 ##及 ##苏 ##黄 ##一 ##辈 ##人 ##可 ##与 ##发 ##吾 ##狂 ##言 ##者 进 ##德 ##， ##则 ##孝 ##悌 ##仁 ##义 ##是 ##也 ##； ##修 ##业 ##， ##则 ##诗 ##文 ##作 ##字 ##是 ##也]==
#
#
#
#
# ==[##有 ##二 ##日 ##有 ##不 ##， ##， ##一 ##自 ##， ##以 ##弟 ##日 ##书 ##， ##人 ##， ##一 ##， ##人 ##日 ##未 ##大 ##， ##之 ##弟 ##来 ##家 ##， ##则 ##中 ##， ##家 ##， ##自 ##则 ##也 ##中 ##一 ##中 ##生 ##十 ##行 ##， ##不 ##不 ##之 ##之 ##也 ##， ##也 ##如 ##已 ##无 ##， ##不 ##不 ##不 ##也 ##， ##可 ##人 ##无 ##， ##皆 ##自]==
# ==[十 ##二 ##日 ##申 ##刻 ##， ##代 ##一 ##自 ##县 ##归 ##， ##接 ##弟 ##手 ##书 ##， ##具 ##审 ##一 ##切 十 ##三 ##日 ##未 ##刻 ##文 ##辅 ##卿 ##来 ##家 ##， ##病 ##势 ##甚 ##重 ##， ##自 ##醴 ##陵 ##带 ##一 ##医 ##生 ##偕 ##行 ##， ##似 ##是 ##瘟 ##疫 ##之 ##证 ##， ##两 ##耳 ##已 ##聋 ##， ##昏 ##迷 ##不 ##醒 ##， ##问 ##作 ##诸 ##语 ##， ##皆 ##惦]==
#
#
#
#
# ==[##实 ##皆 ##在 ##则 ##也 ##， ##无 ##年 ##， ##人 ##人 ##则 ##弟 ##中 ##， ##自 ##则 ##理 ##有 ##之 ##， ##日 ##来 ##之 ##家 ##来 ##不 ##之 ##自 ##， ##日 ##弟 ##弟 ##无 ##来 ##无 ##， ##心 ##也 ##事 ##之 ##至 ##， ##之 ##解 ##不 ##之 ##自 ##十 ##也 ##自 ##亦 ##也 ##十 ##此 ##则 ##， ##以 ##自 ##， ##事 ##不 ##， ##之 ##也 ##理 ##为 ##之 ##大 ##则]==
# ==[英 ##夷 ##在 ##广 ##东 ##， ##今 ##年 ##复 ##请 ##人 ##城 ##； ##徐 ##总 ##督 ##办 ##理 ##有 ##方 ##， ##外 ##夷 ##折 ##服 ##竟 ##不 ##入 ##城 ##， ##从 ##此 ##永 ##无 ##夷 ##祸 ##， ##圣 ##心 ##嘉 ##悦 ##之 ##至 ##！ ##术 ##帮 ##每 ##言 ##皇 ##上 以 ##后 ##务 ##宜 ##力 ##除 ##此 ##病 ##， ##以 ##吴 ##（ ##木 ##云 ##） ##台 ##凌 ##荻 ##舟 ##为 ##眼 ##前 ##之 ##大 ##戒]==
#
#
#
#
# ==[##则 ##无 ##， ##其 ##， ##其 ##不 ##之 ##自 ##， ##所 ##以 ##来 ##之 ##一 ##生 ##， ##而 ##无 ##其 ##之 ##也 ##其 ##月 ##则 ##自 ##一 ##， ##自 ##中 ##， ##年 ##， ##如 ##， ##则 ##，]==
# ==[傲 ##气 ##既 ##长 ##， ##终 ##不 ##进 ##功 ##， ##所 ##以 ##潦 ##倒 ##一 ##生 ##， ##而 ##无 ##寸 ##进 ##也 三 ##月 ##则 ##订 ##一 ##本 ##， ##自 ##乙 ##未 ##年 ##起 ##， ##今 ##三 ##十 ##本 ##矣]==
#
#
#
#
# ==[##也 ##亲 ##大 ##人 ##则 ##， ##十 ##一 ##一 ##， ##自 ##， ##， ##亦 ##也 ##也 ##家 ##， ##， ##不 ##一 ##也]==
# ==[父 ##母 ##亲 ##大 ##人 ##万 ##福 ##金 ##安 十 ##月 ##廿 ##二 ##， ##奉 ##到 ##手 ##谕 ##， ##敬 ##悉 ##一 ##切]==
#
#
#
#
# ==[##则 ##中 ##一 ##前 ##之 ##弟 ##， ##父 ##亲 ##理 ##则 ##， ##余 ##已 ##也 ##心 ##此 ##， ##之 ##， ##中 ##， ##为 ##自 ##自 ##， ##亦 ##不 ##一 ##其 ##不 ##， ##人 ##弟 ##皆 ##一 ##， ##也 ##， ##之 ##大 ##人 ##则 ##亦 ##此 ##事]==
# ==[黎 ##樾 ##乔 ##老 ##前 ##辈 ##处 ##， ##父 ##亲 ##未 ##去 ##辞 ##行 ##， ##男 ##已 ##道 ##达 ##此 ##意 即 ##见 ##制 ##台 ##留 ##朱 ##公 ##， ##亦 ##造 ##福 ##一 ##邑 ##不 ##小 ##， ##诸 ##弟 ##皆 ##宜 ##极 ##力 ##助 ##父 ##大 ##人 ##办 ##成 ##此 ##事]==
#
#
#
#
# ==[##人 ##二 ##者 ##为 ##， ##作 ##为 ##， ##得 ##十 ##则 ##我 ##之 ##十 ##也 ##， ##得 ##， ##则 ##我 ##之 ##其 ##也 ##不 ##日 ##一 ##其 ##可 ##， ##自 ##也 ##不 ##， ##， ##日 ##十 ##事 ##自 ##日 ##， ##一 ##其 ##， ##， ##也 ##则 ##之 ##一 ##来 ##而 ##为 ##事 ##也 ##皆 ##也 ##， ##则 ##家 ##自 ##日 ##日]==
# ==[此 ##二 ##者 ##由 ##我 ##作 ##主 ##， ##得 ##尺 ##则 ##我 ##之 ##尺 ##也 ##， ##得 ##寸 ##则 ##我 ##之 ##寸 ##也 今 ##日 ##进 ##一 ##分 ##德 ##， ##便 ##算 ##积 ##了 ##一 ##升 ##谷 ##； ##明 ##日 ##修 ##一 ##分 ##业 ##， ##又 ##算 ##馀 ##了 ##一 ##文 ##钱 ##； ##德 ##业 ##并 ##增 ##， ##则 ##家 ##私 ##日 ##起]==
#
#
#
#
# ==[##又 ##自 ##之 ##家 ##而 ##生 ##日 ##有 ##， ##， ##事 ##无 ##， ##与 ##诸 ##弟 ##无]==
# ==[兹 ##将 ##艮 ##峰 ##先 ##生 ##日 ##课 ##， ##钞 ##三 ##叶 ##付 ##归 ##， ##与 ##诸 ##弟 ##看]==
#
#
#
#
# ==[##人 ##二 ##弟 ##无 ##年 ##一 ##理 ##， ##来 ##事 ##无 ##则 ##， ##信 ##中 ##之 ##也 ##则 ##， ##自 ##自 ##， ##其 ##十 ##来 ##其 ##则 ##日 ##来 ##则 ##亦 ##， ##弟 ##不 ##即 ##如 ##我 ##家 ##， ##皆]==
# ==[盖 ##植 ##弟 ##今 ##年 ##一 ##病 ##， ##百 ##事 ##荒 ##废 ##， ##场 ##中 ##之 ##患 ##目 ##疾 ##， ##自 ##难 ##见 ##长 恰 ##好 ##初 ##九 ##日 ##小 ##珊 ##来 ##拜 ##寿 ##， ##是 ##夜 ##余 ##即 ##至 ##小 ##珊 ##家 ##久 ##谈]==
#
#
#
#
# ==[##则 ##也 ##则 ##之 ##于 ##书 ##， ##之 ##十 ##， ##而 ##， ##一 ##于 ##自 ##之 ##自 ##， ##也 ##不 ##之 ##之 ##， ##而 ##其 ##不 ##可 ##日 ##， ##所 ##以 ##不 ##其 ##皆 ##亦 ##其 ##实 ##则 ##在 ##则 ##， ##亦 ##之 ##心 ##之 ##如 ##人 ##已 ##也]==
# ==[官 ##索 ##钱 ##粮 ##于 ##书 ##吏 ##之 ##手 ##， ##犹 ##索 ##食 ##于 ##虎 ##狼 ##之 ##口 ##， ##再 ##四 ##求 ##之 ##， ##而 ##终 ##不 ##肯 ##吐 ##， ##所 ##以 ##积 ##成 ##巨 ##亏 并 ##非 ##实 ##欠 ##在 ##民 ##， ##亦 ##非 ##官 ##之 ##侵 ##蚀 ##人 ##已 ##也]==
#
#
#
#
# ==[##也 ##亲 ##大 ##人 ##者 ##也 ##一 ##， ##无 ##， ##十 ##日 ##， ##其 ##父 ##亲 ##于 ##月 ##其 ##理 ##日 ##也 ##也 ##， ##其 ##， ##父 ##， ##人 ##也 ##可 ##无 ##， ##及 ##弟 ##家 ##，]==
# ==[父 ##母 ##亲 ##大 ##人 ##万 ##福 ##金 ##安 四 ##月 ##十 ##四 ##日 ##， ##接 ##奉 ##父 ##亲 ##三 ##月 ##初 ##九 ##日 ##手 ##谕 ##， ##并 ##叔 ##父 ##大 ##人 ##贺 ##喜 ##手 ##示 ##， ##及 ##四 ##弟 ##家 ##书]==
#
#
#
#
# ==[##， ##， ##已 ##， ##生 ##其 ##， ##， ##之 ##理 ##， ##又 ##之 ##其 ##其 ##大 ##可 ##之 ##以 ##亦 ##， ##之 ##理 ##， ##即 ##也 ##物 ##也]==
# ==[郑 ##小 ##珊 ##处 ##， ##小 ##隙 ##已 ##解 究 ##其 ##敬 ##身 ##之 ##理 ##， ##又 ##博 ##究 ##其 ##立 ##齐 ##坐 ##尸 ##以 ##敬 ##身 ##之 ##理 ##， ##即 ##格 ##物 ##也]==
#
#
#
#
# ==[##皆 ##大 ##人 ##则 ##其 ##自 ##一 ##， ##， ##子 ##月 ##十 ##日 ##， ##在 ##也 ##日 ##父 ##之 ##亲 ##， ##为 ##则 ##所 ##家 ##信 ##， ##中 ##月 ##十 ##日 ##， ##于 ##， ##人 ##其 ##一 ##信 ##， ##则 ##有 ##弟 ##有 ##弟 ##， ##中]==
# ==[父 ##亲 ##大 ##人 ##万 ##福 ##金 ##安 ##， ##自 ##闰 ##三 ##月 ##十 ##四 ##日 ##， ##在 ##都 ##门 ##拜 ##送 ##父 ##亲 ##， ##嗣 ##后 ##共 ##接 ##家 ##信 ##五 ##封 五 ##月 ##十 ##五 ##日 ##， ##父 ##亲 ##到 ##长 ##沙 ##发 ##信 ##， ##内 ##有 ##四 ##弟 ##信 ##， ##六 ##弟 ##文 ##章 ##五 ##首]==
#
#
#
#
# ==[##则 ##来 ##其 ##则 ##日 ##小 ##来 ##则 ##亦 ##， ##一 ##不 ##即 ##至 ##家 ##， ##以 ##不 ##弟 ##日 ##与 ##也 ##来 ##人 ##， ##人 ##于 ##也 ##其 ##， ##理 ##此 ##二 ##不 ##， ##， ##以 ##之 ##之 ##， ##则]==
# ==[恰 ##好 ##初 ##九 ##日 ##小 ##珊 ##来 ##拜 ##寿 ##， ##是 ##夜 ##余 ##即 ##至 ##小 ##珊 ##家 ##久 ##谈 十 ##三 ##日 ##与 ##岱 ##云 ##合 ##队 ##， ##请 ##小 ##珊 ##吃 ##饭 ##， ##从 ##此 ##欢 ##笑 ##如 ##初 ##， ##前 ##隙 ##盖 ##释 ##矣]==
#
#
#
#
# ==[##， ##日 ##所 ##则 ##之 ##书 ##， ##也 ##为 ##皆 ##物 ##也 ##， ##其 ##则 ##， ##之 ##， ##虽 ##不 ##无 ##自 ##， ##必 ##即 ##自 ##， ##， ##， ##而 ##书 ##之 ##于 ##， ##， ##， ##所 ##则 ##之 ##书 ##， ##自 ##也 ##皆 ##也 ##， ##之 ##， ##一]==
# ==[每 ##日 ##所 ##看 ##之 ##书 ##， ##句 ##句 ##皆 ##物 ##也 尽 ##其 ##慎 ##独 ##之 ##严 ##， ##虽 ##妄 ##念 ##偶 ##动 ##， ##必 ##即 ##时 ##克 ##治 ##， ##而 ##著 ##之 ##于 ##书 ##， ##故 ##所 ##卖 ##之 ##书 ##， ##句 ##句 ##皆 ##切 ##身 ##之 ##要 ##药]==
#
#
#
#
# ==[##父 ##来 ##， ##十 ##则 ##， ##之 ##， ##所 ##气 ##无 ##， ##则 ##无 ##其 ##为 ##自 ##十 ##月 ##其 ##一 ##日 ##其 ##日 ##则 ##， ##日 ##一 ##可 ##之 ##中 ##自 ##不 ##； ##其 ##理 ##所 ##与 ##有 ##父 ##， ##实 ##不 ##一 ##也 ##之 ##日 ##， ##不 ##大 ##人 ##中 ##， ##即 ##为 ##之 ##日 ##人]==
# ==[精 ##神 ##愈 ##用 ##则 ##愈 ##出 ##， ##阳 ##气 ##愈 ##提 ##则 ##愈 ##盛 余 ##自 ##十 ##月 ##初 ##一 ##起 ##记 ##日 ##课 ##， ##念 ##念 ##欲 ##改 ##过 ##自 ##新 ##； ##思 ##从 ##前 ##与 ##小 ##珊 ##有 ##隙 ##， ##实 ##是 ##一 ##朝 ##之 ##忿 ##， ##不 ##近 ##人 ##情 ##， ##即 ##欲 ##登 ##门 ##谢 ##罪]==
#
#
#
#
# ==[##有 ##则 ##皆 ##也 ##， ##不 ##， ##有 ##无 ##之 ##其 ##生 ##有 ##有 ##， ##家 ##则 ##心 ##成 ##为 ##一 ##则 ##事 ##不 ##自 ##弟 ##之 ##一 ##则 ##， ##事 ##也 ##也 ##十 ##也 ##， ##弟 ##之 ##也 ##， ##弟 ##所 ##之 ##也 ##， ##日 ##， ##皆 ##来 ##二 ##者 ##有 ##我 ##可 ##有 ##， ##， ##不 ##则 ##我 ##之 ##不 ##也 ##， ##之 ##处 ##则 ##， ##之 ##其 ##也]==
# ==[弟 ##性 ##褊 ##急 ##似 ##余 ##， ##恐 ##拂 ##郁 ##或 ##生 ##肝 ##疾 ##， ##幸 ##息 ##心 ##忍 ##耐 ##为 ##要 ##！ ##兹 ##趁 ##便 ##； ##寄 ##一 ##缄 ##， ##托 ##黄 ##宅 ##转 ##遁 ##， ##弟 ##接 ##到 ##后 ##， ##弟 ##接 ##到 ##后 ##， ##望 ##（ ##上 此 ##二 ##者 ##由 ##我 ##作 ##主 ##， ##得 ##尺 ##则 ##我 ##之 ##尺 ##也 ##， ##得 ##寸 ##则 ##我 ##之 ##寸 ##也]==
#
#
#
#
# ==[##日 ##已 ##与 ##为 ##中 ##日 ##， ##之 ##大 ##二 ##在 ##之 ##已 ##日 ##， ##其 ##有 ##， ##其 ##弟 ##， ##为 ##之 ##， ##二 ##事 ##不 ##必 ##其 ##心 ##十 ##父 ##之 ##则 ##， ##， ##而 ##之 ##中 ##信 ##也 ##， ##， ##无 ##一 ##得 ##， ##实 ##不 ##家 ##心]==
# ==[王 ##仕 ##四 ##已 ##善 ##为 ##遣 ##回 ##， ##率 ##五 ##大 ##约 ##在 ##粮 ##船 ##回 ##， ##现 ##尚 ##未 ##定 ##； ##渠 ##身 ##体 ##平 ##安 ##， ##二 ##妹 ##不 ##必 ##挂 ##心 叔 ##父 ##之 ##病 ##， ##男 ##累 ##求 ##详 ##信 ##直 ##告 ##， ##至 ##今 ##未 ##得 ##， ##实 ##不 ##放 ##心]==
#
#
#
#
# ==[##也 ##弟 ##自 ##则 ##有 ##大 ##， ##， ##则 ##也 ##自 ##则 ##已 ##有 ##则 ##， ##， ##自 ##已 ##则 ##如 ##， ##日 ##可 ##， ##自 ##月 ##其 ##不 ##于 ##自 ##余 ##， ##， ##也 ##已 ##， ##， ##， ##书 ##则 ##之 ##自 ##， ##文 ##中 ##日 ##理 ##得 ##， ##， ##十 ##人 ##则 ##中 ##， ##不 ##则 ##生 ##不 ##则 ##有]==
# ==[九 ##弟 ##功 ##课 ##有 ##常 ##， ##《 ##礼 ##记 ##》 ##九 ##本 ##已 ##点 ##完 ##， ##《 ##鉴 ##》 ##已 ##看 ##至 ##《 ##三 ##国 ##》 ##， ##《 ##斯 ##文 ##精 ##粹 ##》 ##诗 ##文 ##， ##各 ##已 ##读 ##半 ##本 ##， ##诗 ##略 ##进 ##功 ##， ##文 ##章 若 ##调 ##理 ##得 ##宜 ##， ##半 ##月 ##当 ##可 ##痊 ##愈 ##， ##复 ##原 ##则 ##尚 ##不 ##易 ##易]==
#
#
#
#
# ==[##则 ##子 ##， ##之 ##而 ##之 ##， ##其 ##皆 ##有 ##处 ##， ##无 ##一 ##不 ##自 ##， ##其 ##皆 ##来 ##之 ##理 ##无 ##可 ##为 ##在 ##之 ##则 ##书 ##， ##， ##以 ##自 ##十 ##月 ##来 ##， ##已 ##， ##所 ##十 ##， ##家 ##， ##弟 ##也 ##二 ##中 ##无 ##日 ##， ##与 ##自 ##弟 ##自]==
# ==[何 ##子 ##贞 ##之 ##谈 ##字 ##， ##其 ##精 ##妙 ##处 ##， ##无 ##一 ##不 ##合 ##， ##其 ##谈 ##诗 ##尤 ##最 ##符 ##契 子 ##贞 ##深 ##喜 ##吾 ##诗 ##， ##故 ##吾 ##自 ##十 ##月 ##来 ##， ##已 ##作 ##诗 ##十 ##八 ##首 ##， ##兹 ##抄 ##二 ##叶 ##付 ##回 ##， ##与 ##诸 ##弟 ##阅]==
#
#
#
#
# ==[##有 ##月 ##自 ##一 ##， ##于 ##之 ##弟 ##在 ##， ##而 ##所 ##人 ##信 ##， ##自 ##日 ##中 ##日 ##其 ##已 ##， ##甚 ##一 ##一 ##可]==
# ==[十 ##月 ##廿 ##一 ##， ##接 ##九 ##弟 ##在 ##长 ##沙 ##所 ##发 ##信 ##， ##内 ##途 ##中 ##日 ##记 ##六 ##页 ##， ##外 ##药 ##子 ##一 ##包]==

# %%
class TextClsDataset(Dataset):
    def __init__(self):
        self.tokenizer = Tokenizer.from_file("./model_save/my_tokenizer.json")
        lines = open("./头条data/toutiao_cat_data.txt",encoding="utf8").readlines()
        index = 0
        self.tagmap = {}
        data = []
        for line in lines:
            ts = line.strip().split("_!_")
            if len(ts)!=5:
                continue
            id = ts[1]
            label = ts[2]
            text = ts[3]
            if not id in self.tagmap:
                self.tagmap[id] = {"index":index,"label":label}
                index+=1
            data.append([text,self.tagmap[id]["index"]])
        self.data = data

    def __len__(self):
        return len(self.data)

    def __getitem__(self,index):
        text, label = self.data[index]
        ids = [2] + self.tokenizer.encode(text[:101]).ids + [3]
        if len(ids)<103:
            ids += [1 for _ in range(103-len(ids))]
        return np.array(ids,dtype=np.int64),label

# %%
class TextClsModel(nn.Module):
    def __init__(self,config,label_count):
        super(TextClsModel,self).__init__()
        self.transformer = Transformer(config)
        self.f1 = nn.Linear(config.hidden_dim,label_count).to(config.device)

    def forward(self,x):
        p,_ = self.transformer(x)
        return self.f1(p)

def train():
    data = TextClsDataset()
    loader = DataLoader(data,batch_size=20,shuffle=True)

    config = ModelConfig(device = torch.device("cuda:0"))
    config.load("./model_save/config.json")
    model = TextClsModel(config,len(data.tagmap))
    model.transformer.load_state_dict(torch.load("./model_save/model_pretrain_done.pt",map_location=config.device))
    loss_function = CrossEntropyLoss()
    epoch = 20
    optimizer = optim.Adam(model.parameters(),lr=1e-4)
    step = 0
    pbar = tqdm(loader)
    for e in range(epoch):
        for ids,label in pbar:
            ids = ids.to(config.device)
            label = label.to(config.device)
            p = model(ids)
            optimizer.zero_grad()
            loss = loss_function(p,label)
            loss.backward()
            optimizer.step()
            step+=1
            err = 0
            pLabel = torch.argmax(p,dim=1)
            for i in range(pLabel.size(0)):
                if int(pLabel[i]) != int(label[i]):
                    err += 1
            acc = 1
            if err != 0:
                acc = (pLabel.size(0)-err)/pLabel.size(0)
            desc = "[{}/{}][{}][{:.4f}][{:.4f}]".format(e+1,epoch,step,float(loss),acc)
            pbar.set_description(desc)

# %%
train()
# Out:
# [1/20][19135][2.4128][0.1250]: 100%|██████████| 19135/19135 [05:10<00:00, 61.66it/s]
